# %% [markdown]
# # **Table of contents:**
#
# - Image Translation
# - **Image Scaling**
# - Image Shearing
#  - Shearing in the x-axis Direction
#  - Shearing in the y-axis Direction
# - Image Reflection
# - Image Rotation
# - Image Cropping

# %% [markdown]
# ---

# %% [markdown]
# ## **Scaling**

# %% [markdown]
# The technique of resizing a digital image is known as image scaling. Although OpenCV includes a built-in method called [cv2.resize()](https://docs.opencv.org/4.x/da/d54/group__imgproc__transform.html#ga47a974309e9102f5f08231edc7e7529d), we'll still use matrix multiplication to complete the transformation. The scaling matrix is depicted below:

# %% [markdown]
# <img src="https://i.ibb.co/qMfLk6V/Unknown-4.png" alt="Unknown-4" border="0">

# %% [markdown]
# > Sx and Sy are the scaling factors for x-axis and y-axis, respectively.

# %% [markdown]
# ---

# %% [markdown]
# ### Python Code:

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# read the input image
img = cv2.imread("ronaldo.jpg")
# convert from BGR to RGB so we can plot using matplotlib
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# disable x & y axis
plt.axis('off')
# show the image
plt.imshow(img)
plt.show()
# get the image shape
rows, cols, dim = img.shape

#transformation matrix for Scaling
M = np.float32([[1.8, 0  , 0],
            	[0,   1.4, 0],
            	[0,   0,   1]])

# apply a perspective transformation to the image
scaled_img = cv2.warpPerspective(img,M,(cols*2,rows*2))
# disable x & y axis
plt.axis('off')
# show the resulting image
plt.imshow(scaled_img)
plt.show()
# save the resulting image to disk
plt.imsave("ronaldo_scaled.jpg", scaled_img)
