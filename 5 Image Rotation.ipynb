# %% [markdown]
# # **Table of contents:**
#
# - Image Translation
# - Image Scaling
# - Image Shearing
#  - Shearing in the x-axis Direction
#  - Shearing in the y-axis Direction
# - Image Reflection
# - **Image Rotation**
# - Image Cropping

# %% [markdown]
# ---

# %% [markdown]
# ## **Rotation**

# %% [markdown]
# Rotation is a mathematical term that describes the motion of a certain space while preserving at least one point. Matching, alignment, and other image-based algorithms use picture rotation as a typical image processing routine.

# %% [markdown]
# The transformation matrix of rotation is shown in the below figure, where theta (θ) is the angle of rotation:

# %% [markdown]
# <img src="https://i.ibb.co/34Tf5jq/Unknown-7.png" alt="Unknown-7" border="0">

# %% [markdown]
# ---

# %% [markdown]
# ### Python Code:

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# read the input image
img = cv2.imread("ronaldo.jpg")
# convert from BGR to RGB so we can plot using matplotlib
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# disable x & y axis
plt.axis('off')
# show the image
plt.imshow(img)
plt.show()
# get the image shape
rows, cols, dim = img.shape

#angle from degree to radian
angle = np.radians(20)

#transformation matrix for Rotation
M = np.float32([[np.cos(angle), -(np.sin(angle)), 0],
            	[np.sin(angle), np.cos(angle), 0],
            	[0, 0, 1]])

# apply a perspective transformation to the image
rotated_img = cv2.warpPerspective(img, M, (int(cols),int(rows)))
# disable x & y axis
plt.axis('off')
# show the resulting image
plt.imshow(rotated_img)
plt.show()
# save the resulting image to disk
plt.imsave("ronaldo_rotated.jpg", rotated_img)
